# %% [markdown]
# Pour ce projet, nous allons utiliser des LLM (Large Language Models).
#
# Pour cela, il sera nécessaire de créer un token OpenAI : Cela coûte 5 euros, qui correspond à la somme minimum pour activer un token OpenAI. Pendant le projet, nous ne dépenserons que des centimes, ce qui signifie que le solde restant pourra être utilisé pour d'autres projets à venir.
#
# *N.B.: Il est également possible d'utiliser des bibliothèques gratuites. C'est le cas d'Ollama, qui permet d'accéder à des modèles tels que Llama 3, qui sont suffisants pour répondre aux besoins de ce projet.*

# %%
from dotenv import load_dotenv
import os

load_dotenv()
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

# %% [markdown]
# # Chargement des données
# Téléchargement du fichier JSONL meta.jsonl, qui contient des descriptions de produits.

# %%
import pandas as pd

df_meta = pd.read_json('data/meta.jsonl', lines=True)
df_meta.head()
# Out:
#                main_category  \
# 0  Cell Phones & Accessories
# 1  Cell Phones & Accessories
# 2  Cell Phones & Accessories
# 3  Cell Phones & Accessories
# 4  Cell Phones & Accessories
#
#                                                title  average_rating  \
# 0  ARAREE Slim Diary Cell Phone Case for Samsung ...             3.8
# 1  Bastmei for OnePlus 7T Case Extremely Light Ul...             4.4
# 2  Wireless Fones Branded New Iphone 5C/LITE Hot ...             4.0
# 3  iPhone 6 Plus + Case, DandyCase Perfect PATTER...             4.0
# 4  Case for Galaxy S6/S6 Edge, Thin Translucent V...             4.0
#
#    rating_number                                           features  \
# 0              5  [Genuine Cow leather with 6 different colors, ...
# 1            177  [Ultra-thin & Ultra-light: The ultra slim fit ...
# 2              2                                                 []
# 3             15  [Slim-Fit design for the iPhone 6 Plus (5.5" s...
# 4              1                                                 []
#
#                                          description  price  \
# 0  [JUST LOOK, You can tell the difference. Make ...    NaN
# 1                                                 []  11.98
# 2                                                 []    NaN
# 3  [Case does not need to be removed for charging...    NaN
# 4                                                 []    NaN
#
#                                               images videos           store  \
# 0  [{'thumb': 'https://m.media-amazon.com/images/...     []          araree
# 1  [{'thumb': 'https://m.media-amazon.com/images/...     []         Bastmei
# 2  [{'thumb': 'https://m.media-amazon.com/images/...     []  WIRELESS FONES
# 3  [{'thumb': 'https://m.media-amazon.com/images/...     []       DandyCase
# 4  [{'thumb': 'https://m.media-amazon.com/images/...     []           7Pite
#
#                                           categories  \
# 0  [Cell Phones & Accessories, Cases, Holsters & ...
# 1  [Cell Phones & Accessories, Cases, Holsters & ...
# 2    [Cell Phones & Accessories, iPhone Accessories]
# 3    [Cell Phones & Accessories, iPhone Accessories]
# 4  [Cell Phones & Accessories, Cases, Holsters & ...
#
#                                              details parent_asin  \
# 0  {'Product Dimensions': '3.35 x 0.59 x 6.18 inc...  B013SK1JTY
# 1  {'Package Dimensions': '7.6 x 4.29 x 0.75 inch...  B07ZPSG8P5
# 2  {'Item model number': 'Apple Iphone 5C', 'Othe...  B00GKR3L12
# 3  {'Product Dimensions': '5.43 x 0.28 x 2.64 inc...  B00PB8U8BW
# 4  {'Package Dimensions': '8.31 x 3.74 x 0.55 inc...  B07D3RHSRV
#
#    bought_together  subtitle  author
# 0              NaN       NaN     NaN
# 1              NaN       NaN     NaN
# 2              NaN       NaN     NaN
# 3              NaN       NaN     NaN
# 4              NaN       NaN     NaN

# %% [markdown]
# Suppression des descriptions vides

# %%
df_meta = df_meta[df_meta['description'].apply(lambda x: len(x) > 0)]
df_meta.head()
# Out:
#                 main_category  \
# 0   Cell Phones & Accessories
# 3   Cell Phones & Accessories
# 5   Cell Phones & Accessories
# 7   Cell Phones & Accessories
# 11          Sports & Outdoors
#
#                                                 title  average_rating  \
# 0   ARAREE Slim Diary Cell Phone Case for Samsung ...             3.8
# 3   iPhone 6 Plus + Case, DandyCase Perfect PATTER...             4.0
# 5   Rikki Knight 3D Chevron Peach on White with An...             1.0
# 7   Piel Frama Wallet Case for Samsung Galaxy Nexu...             5.0
# 11  BCSLINE Outdoor Exercise Jogging Armband Case,...             3.2
#
#     rating_number                                           features  \
# 0               5  [Genuine Cow leather with 6 different colors, ...
# 3              15  [Slim-Fit design for the iPhone 6 Plus (5.5" s...
# 5               1  [Includes attached ribbon Wristlet Strap., Bla...
# 7               1  [Sync through travel cable, Removable belt cli...
# 11              5  [Practical&Beautiful high quality Armband, Exe...
#
#                                           description  price  \
# 0   [JUST LOOK, You can tell the difference. Make ...    NaN
# 3   [Case does not need to be removed for charging...    NaN
# 5   [The Rikki Knight new Flip Wallet iPhone case ...  22.42
# 7   [Handcrafted in Spain by Leather artisans, pie...    NaN
# 11  [Features: Carry your phone around with style!...    NaN
#
#                                                images videos         store  \
# 0   [{'thumb': 'https://m.media-amazon.com/images/...     []        araree
# 3   [{'thumb': 'https://m.media-amazon.com/images/...     []     DandyCase
# 5   [{'thumb': 'https://m.media-amazon.com/images/...     []  Rikki Knight
# 7   [{'thumb': 'https://m.media-amazon.com/images/...     []    Piel Frama
# 11  [{'thumb': 'https://m.media-amazon.com/images/...     []      BCSCasek
#
#                                            categories  \
# 0   [Cell Phones & Accessories, Cases, Holsters & ...
# 3     [Cell Phones & Accessories, iPhone Accessories]
# 5     [Cell Phones & Accessories, iPhone Accessories]
# 7   [Cell Phones & Accessories, Cases, Holsters & ...
# 11  [Cell Phones & Accessories, Cases, Holsters & ...
#
#                                               details parent_asin  \
# 0   {'Product Dimensions': '3.35 x 0.59 x 6.18 inc...  B013SK1JTY
# 3   {'Product Dimensions': '5.43 x 0.28 x 2.64 inc...  B00PB8U8BW
# 5   {'Product Dimensions': '5 x 2.5 x 0.1 inches',...  B00JIFK1HA
# 7   {'Product Dimensions': '5.71 x 3.15 x 0.79 inc...  B0071OC36W
# 11  {'Brand Name': 'BCSCasek', 'Color': 'Blue', 'M...  B00JI55D2I
#
#     bought_together  subtitle  author
# 0               NaN       NaN     NaN
# 3               NaN       NaN     NaN
# 5               NaN       NaN     NaN
# 7               NaN       NaN     NaN
# 11              NaN       NaN     NaN

# %% [markdown]
# # Prétraitement et segmentation des textes
# Installation de la librairie LangChain (alternative: LlamaIndex)

# %%
#!pip install langchain

# %% [markdown]
# Division des longues descriptions en morceaux de taille appropriée avec RecursiveCharacterTextSplitter.
# - Taille des morceaux (chunk_size) : par exemple, 512 caractères.
# - Chevauchement entre les morceaux (chunk_overlap) : 128 caractères.

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

def preprocess_and_split_descriptions(descriptions, chunk_size=256, chunk_overlap=128):
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=chunk_size,
        chunk_overlap=chunk_overlap
    )
    split_texts = []
    
    for desc in descriptions:
        if isinstance(desc, list):
            desc = " ".join(desc)
        elif pd.isna(desc):
            desc = ""
        
        chunks = text_splitter.split_text(desc)
        split_texts.append(chunks)
    
    return split_texts

df_meta["description_chunks"] = preprocess_and_split_descriptions(df_meta["description"])

print(df_meta[["description_chunks"]].head(3))
# Out:
#                                   description_chunks
# 0  [JUST LOOK, You can tell the difference. Make ...
# 3  [Case does not need to be removed for charging...
# 5  [The Rikki Knight new Flip Wallet iPhone case ...

# %% [markdown]
# ### *Remarque :*
# *La taille de 256 tokens permet de donner du sens aux informations tout en gardant une granularité permettant de conserver un volume raisonnable d'informations dans chaque chunk, idéal pour des tâches comme la recherche ou la réponse à des questions.*
#
# *Le chevauchement de 128 (soit 50 % du chunk), garantie que des parties importantes du texte apparaissent dans plusieurs chunks.*

# %% [markdown]
# # Création d'un index vectoriel
# Génération des embeddings pour chaque morceau de texte à l’aide du modèle d’embedding Sentence Embeddings de HuggingFace (all-MiniLM-L6-v2).
#
# Il est également possible d'utiliser OllamaEmbeddings.

# %%
sentences_list = df_meta["description_chunks"].explode().dropna().unique().tolist()
sentences_list
# Out:
# ['JUST LOOK, You can tell the difference. Make everyday more convenient, it is slim but has big rooms. If you are looking for a rich and luxurious appearance, look no further. These double shoulders are the perfect leather for creating attractive finished',
#  "rich and luxurious appearance, look no further. These double shoulders are the perfect leather for creating attractive finished belts, straps and wallets. It doesn't only show the perfect weight for accessories where rugged durability is needed but also",
#  "belts, straps and wallets. It doesn't only show the perfect weight for accessories where rugged durability is needed but also has a natural finish and coarse grain.",
#  'Case does not need to be removed for charging. Camera opening allows unobstructed use of camera and flash. DandyCase proudly presents the premium "PERFECT PATTERN" from the line of stylish cases that will make your friends jealous! Stand out from the rest',
#  'the premium "PERFECT PATTERN" from the line of stylish cases that will make your friends jealous! Stand out from the rest and show off your Apple iPhone 6 Plus with these one of a kind cases. These cases are made of a durable, yet slightly flexible, TPU',
#  "show off your Apple iPhone 6 Plus with these one of a kind cases. These cases are made of a durable, yet slightly flexible, TPU material that won't stretch or tear and the patterns wont chip, fade, or peel. DandyCase PERFECT PATTERN cases come with a",
#  "TPU material that won't stretch or tear and the patterns wont chip, fade, or peel. DandyCase PERFECT PATTERN cases come with a lifetime warranty against damage during normal use. Each case comes in DandyCase retail packaging. This is a universal hard case",
#  'warranty against damage during normal use. Each case comes in DandyCase retail packaging. This is a universal hard case for the 5.5" Apple iPhone 6 Plus. It will NOT fit the iPhone 6 or iPhone 5S. DandyCase PERFECT PATTERN cases are available in over 100',
#  '5.5" Apple iPhone 6 Plus. It will NOT fit the iPhone 6 or iPhone 5S. DandyCase PERFECT PATTERN cases are available in over 100 fun patterns! Please note: this case was designed to be as slim as possible while still providing protection against scrapes,',
#  'fun patterns! Please note: this case was designed to be as slim as possible while still providing protection against scrapes, scratches, and small drops. If you plan on leaving it in a mud puddle, running over it with your work truck, or kicking it down',
#  'scratches, and small drops. If you plan on leaving it in a mud puddle, running over it with your work truck, or kicking it down the street, we suggest searching for the other big name "Armor" box cases (although they don\'t have the fun patterns that we',
#  'the street, we suggest searching for the other big name "Armor" box cases (although they don\'t have the fun patterns that we do!).',
#  'The Rikki Knight new Flip Wallet iPhone case for iPhone 5C protects your cell phone from scratches dirt, and impact whilst also Providing easy access to all features of your phone. This case also protects your privacy by with the Flip Cover on your screen',
#  'Providing easy access to all features of your phone. This case also protects your privacy by with the Flip Cover on your screen to prevent those around you from reading your on screen messages. Inside of the case features a side slot where you can store',
#  'to prevent those around you from reading your on screen messages. Inside of the case features a side slot where you can store business cards, credit cards, cash, etc. Universal: Verizon - Sprint - AT&T - Unisex, the Rikki Knight Flip Wallet case is the',
#  'business cards, credit cards, cash, etc. Universal: Verizon - Sprint - AT&T - Unisex, the Rikki Knight Flip Wallet case is the perfect Accessory to protect your iPhone in style. Each Rikki Knight image design is part of a larger collection that can be',
#  'perfect Accessory to protect your iPhone in style. Each Rikki Knight image design is part of a larger collection that can be purchased as a matching Accessory to this phone case - such as wristlets, Compact mirrors, Messenger bags, laptop bags, Pencil',
#  'purchased as a matching Accessory to this phone case - such as wristlets, Compact mirrors, Messenger bags, laptop bags, Pencil cases, pen Holder, iPod cases, iPad Nook and Kindle cases, mugs, mouse pads, key chains, and many more. Disclaimer: all images',
#  'cases, pen Holder, iPod cases, iPad Nook and Kindle cases, mugs, mouse pads, key chains, and many more. Disclaimer: all images are printed directly into the material - the texture of the image will always be a flat surface. Any images that appears to be',
#  'are printed directly into the material - the texture of the image will always be a flat surface. Any images that appears to be 3D, textured, or Glittery are flat printed images and are proudly printed in the USA.',
#  'Handcrafted in Spain by Leather artisans, piel frama phone cases are renowned worldwide for their Exquisite quality and workmanship. Piel frama uses only the finest locally-sourced materials, eco-friendly manufacturing techniques and careful attention to',
#  'Piel frama uses only the finest locally-sourced materials, eco-friendly manufacturing techniques and careful attention to detail. The result is a soft, supple Leather product that is extremely durable, ergonomic and that has a minimal impact on the',
#  'detail. The result is a soft, supple Leather product that is extremely durable, ergonomic and that has a minimal impact on the environment. A superior Leather goods manufacturer since 1945, piel frame made their First mobile phone case in 1984, the same',
#  'environment. A superior Leather goods manufacturer since 1945, piel frame made their First mobile phone case in 1984, the same year modern cell phones were introduced. The pioneering case maker uses natural and biodegradable products to Tan and finish the',
#  'modern cell phones were introduced. The pioneering case maker uses natural and biodegradable products to Tan and finish the full-grain Leather materials, as well as in its glues. Every case is carefully cut, assembled and sewn by hand. If you Desire the',
#  'Leather materials, as well as in its glues. Every case is carefully cut, assembled and sewn by hand. If you Desire the look and feel of luxury in handmade Spanish Leather, a piel frame case is the ultimate product for you. More than just lasting',
#  'look and feel of luxury in handmade Spanish Leather, a piel frame case is the ultimate product for you. More than just lasting protection for your technology investment, these cases are truly a work of art.',
#  'Features: Carry your phone around with style!Exercise your right to a great soundtrack with this ultimate workout armband case Package: 1 x Sports Armband. Not include the cell phone. 1 x Bcsline cleaning cloth,Color:randomly .',
#  'MMOBIEL Earspeaker Light Sensor Flex Cable Incl Mic compatible with iPhone XS Max 6.5 inch Earpiece Sound Listening Assembly incl. Screwdrivers Complete set: Set Includes 3 x Screwdriver 1 x Pentalobe 1 x Cross 1 x 0. 6. Tri-Point. Important! By replacing',
#  'Screwdrivers Complete set: Set Includes 3 x Screwdriver 1 x Pentalobe 1 x Cross 1 x 0. 6. Tri-Point. Important! By replacing this assembly, you will permanently lose the face ID function. Compatible with iPhone XS Max 6. 5 Inch A1921/ A2101/ A2102/ A2104',
#  'assembly, you will permanently lose the face ID function. Compatible with iPhone XS Max 6. 5 Inch A1921/ A2101/ A2102/ A2104 (All Carriers) ! Important: Please check the Model Number of your device before purchasing this Item. You will find the Model',
#  '(All Carriers) ! Important: Please check the Model Number of your device before purchasing this Item. You will find the Model Number on your device and / or in the settings. Easy Installation: \xa0Accurate Replacement part used to Replace the broken damaged',
#  'on your device and / or in the settings. Easy Installation: \xa0Accurate Replacement part used to Replace the broken damaged part! Perfect fit. You do not need a Technician to do it. High quality product by MMOBIEL: Each parts are tested before shipment.',
#  'Perfect fit. You do not need a Technician to do it. High quality product by MMOBIEL: Each parts are tested before shipment. Item in Stock!',
#  '2 in 1 Silicone Skin and Hard Shield Fusion Case, protect your phone from scratches and drops.',
#  'What are PopSockets? PopSockets are expanding grips and stands that attach to most phones, tablets, and cases. Add a single PopSocket, or a pair of PopSockets, to the back of almost any mobile device to transform its capabilities. PopSockets "pop" whenever',
#  'or a pair of PopSockets, to the back of almost any mobile device to transform its capabilities. PopSockets "pop" whenever you need a grip, a Stand, an earbud-management system, or just something to play with. Remove your PopSocket by Pulling slowly on the',
#  "a grip, a Stand, an earbud-management system, or just something to play with. Remove your PopSocket by Pulling slowly on the base; you can reposition and Reattach time and time again. You'll always have the exact grip or Stand you need.",
#  'Material: Genuine cowhide Leather  Package include:1Xiphone 6(4.7inch) cover  Product Features:  Easy to insert and remove.  Design to perfectly fit your phone.',
#  'If your cellphone rear panel back cover has crackes or flaws; You should replace it via a new one.Before Ordering; Please confirm what you really need.',
#  'iPhone 6S/6 Case Luxury Aluminum Chrome Coating Hybrid Hard Case. This case using only premium quality materials, the silver color matched with precise full access to ports, buttons and all features without ever having to remove your case means you will',
#  'matched with precise full access to ports, buttons and all features without ever having to remove your case means you will never again have to leave your Apple iPhone 6/6s 4.7 naked and unprotected. With the slim, thin and lightweight design, the case',
#  'again have to leave your Apple iPhone 6/6s 4.7 naked and unprotected. With the slim, thin and lightweight design, the case gives your cellphone a professional, sleek, modern look. Note: color shown in pictures might slightly differ from actual products',
#  'your cellphone a professional, sleek, modern look. Note: color shown in pictures might slightly differ from actual products due to different lightning and color settings.',
#  'Sport Band Compatible with Apple Watch Bands 38mm 40mm 41mm 42mm 44mm 45mm for Women Men,Floral Silicone Printed Fadeless Pattern Replacement Strap Band for iWatch Series 7,Series 3, Series 5,Series 6,Series 4',
#  'Compatible With Amazon: Kindle Fire / Kindle Touch / Samsung? Galaxy S2 Hercules T989 (T-Mobile) / Galaxy S2 Attain i777 (AT&T) / Epic 4G touch (Sprint)/Samsung? SGH-i927 Captivate Glide; Galaxy S2 i9100 / Samsung? Galaxy Nexus / Samsung? N 7000 Galaxy',
#  '/ Epic 4G touch (Sprint)/Samsung? SGH-i927 Captivate Glide; Galaxy S2 i9100 / Samsung? Galaxy Nexus / Samsung? N 7000 Galaxy Note / Samsung? Galaxy S2 Skyrocket / Samsung? Galaxy Note LTE SGH-I717 / Samsung? Galaxy S2 CDMA (U.S.Cellular) R760, Google',
#  'Note / Samsung? Galaxy S2 Skyrocket / Samsung? Galaxy Note LTE SGH-I717 / Samsung? Galaxy S2 CDMA (U.S.Cellular) R760, Google Nexus 7; Samsung Galaxy SIV / S4,HTC One M7',
#  "Product Features. ❤This case is compatible with iPhone 13 Pro Max. ❤100% brand new. The special cute fashion makes it stand out. Wherever you go, you'll have lots of fun and compliments with this case.  ❤ They are made of the highest grade material,",
#  "out. Wherever you go, you'll have lots of fun and compliments with this case.  ❤ They are made of the highest grade material, odorless and harmless to your health. ❤ The back side has strong anti-friction so that you minimize the risk of slipping while",
#  'odorless and harmless to your health. ❤ The back side has strong anti-friction so that you minimize the risk of slipping while holding your phone in your hand. About us. Yonds Queen is committed to creating the most fashionable, cutting-edge products and',
#  'holding your phone in your hand. About us. Yonds Queen is committed to creating the most fashionable, cutting-edge products and the best quality products to bring you a pleasant shopping experience in your leisure life. At the same time, our goal is to',
#  'the best quality products to bring you a pleasant shopping experience in your leisure life. At the same time, our goal is to provide the highest standard of customer service to each and every one of our customers. If you have any questions, you can',
#  'to provide the highest standard of customer service to each and every one of our customers. If you have any questions, you can contact us promptly via email. Package contents. 1 * Cute soft TPU Case',
#  'Features:  -Good quality -Durable 2 layers design, shock absorption -Perfect fit for your LG Stylo 3 / LG Stylus 3 Released in 2017 -Rubberized Polycarbonate Armor outer hard case Silicone Inner layer cushions and shields your phone from damage',
#  'in 2017 -Rubberized Polycarbonate Armor outer hard case Silicone Inner layer cushions and shields your phone from damage -Conveniently designed to provide quick access to all touch controls, features, and ports -Camera lens opening -Access to all buttons',
#  'designed to provide quick access to all touch controls, features, and ports -Camera lens opening -Access to all buttons and controls, no need to remove when charging, plugging in, adjusting volume or switching on/off -Full access to user interface, camera',
#  'no need to remove when charging, plugging in, adjusting volume or switching on/off -Full access to user interface, camera lens, headphone jack, speakerphone and microphone -Secure snap-on back case while Easy to remove -Design: 2 piece combo -Color:',
#  'lens, headphone jack, speakerphone and microphone -Secure snap-on back case while Easy to remove -Design: 2 piece combo -Color: Choose your color  Package Includes: - 1 x Tekcoo Tmajor Series LG Stylo 3 / LG Stylus 3 Case in Tekcoo Retail Package',
#  'USB charger for iphone, mobile phones and other 5V USB devices. How Does Qualcomm Quick Charge 3.0 Work? To help speed up the charge rate the voltage and amperage need to be adjusted. Since they’re both interconnected, and because there’s the component of',
#  'rate the voltage and amperage need to be adjusted. Since they’re both interconnected, and because there’s the component of resistance in there too, the ratios must be monitored and adjusted as the battery is “filled” with its charge.Think of this as',
#  'resistance in there too, the ratios must be monitored and adjusted as the battery is “filled” with its charge.Think of this as filling a pitcher of water. You can fill it with a trickle of water and you won’t risk spilling a single drop – but it will take',
#  'a pitcher of water. You can fill it with a trickle of water and you won’t risk spilling a single drop – but it will take a long time. You can fill it with a firehose, but after a split-second burst there will be water everywhere, and after the hose is',
#  'time. You can fill it with a firehose, but after a split-second burst there will be water everywhere, and after the hose is shut off, you’ll likely see that hardly any water stayed in the pitcher. Instead, as you fill a pitcher, you probably start out',
#  'shut off, you’ll likely see that hardly any water stayed in the pitcher. Instead, as you fill a pitcher, you probably start out fairly slowly until the flow starts going, then gradually open the spigot all the way. As the water level starts getting to the',
#  'fairly slowly until the flow starts going, then gradually open the spigot all the way. As the water level starts getting to the top, you back off the flow rate to make sure you don’t overfill the pitcher and make a mess, eventually filling the last little',
#  'top, you back off the flow rate to make sure you don’t overfill the pitcher and make a mess, eventually filling the last little bit with a trickle.That’s exactly how QC 3.0 works!A 3.0 charger “talks” with the device to coordinate the charge rate, and',
#  'bit with a trickle.That’s exactly how QC 3.0 works!A 3.0 charger “talks” with the device to coordinate the charge rate, and adjusts different voltage settings. All this results in “minimized losses, increased efficiency, and improved thermal performance.”',
#  'different voltage settings. All this results in “minimized losses, increased efficiency, and improved thermal performance.” Why Charge Up to 80% Battery Life? Smartphone batteries charge in two different phases: The first phase is from 0-80% and this',
#  'Why Charge Up to 80% Battery Life? Smartphone batteries charge in two different phases: The first phase is from 0-80% and this phase absorbs huge amount of power at once. The first phase is from 0-80% and this phase absorbs huge amount of power at once.',
#  'phase absorbs huge amount of power at once. The first phase is from 0-80% and this phase absorbs huge amount of power at once. From 81-100%, the battery has to be careful of the power level it absorbs. From 81-100%, the battery has to be careful of the',
#  'From 81-100%, the battery has to be careful of the power level it absorbs. From 81-100%, the battery has to be careful of the power level it absorbs. QC 3.0 increases the process during the first phase four times faster than conventional chargers. Because',
#  'level it absorbs. QC 3.0 increases the process during the first phase four times faster than conventional chargers. Because of its algorithm, it can determine the power level it has to absorb when the phase changes.',
#  "BoxWave Charger Compatible With PBS Kids Playtime Pad.Why pay more for a charger for your Playtime Pad? Get BoxWave's Micro USB Wall Charger Direct! This advanced Micro USB specific Power Adapter is low cost, and designed to charge your Playtime Pad!",
#  'USB Wall Charger Direct! This advanced Micro USB specific Power Adapter is low cost, and designed to charge your Playtime Pad! Delivering 10W of power, the Wall Charger Direct will SAFELY and quickly RAPID-CHARGE your Playtime Pad so you can use it as',
#  'Delivering 10W of power, the Wall Charger Direct will SAFELY and quickly RAPID-CHARGE your Playtime Pad so you can use it as soon as possible. The Wall Charger Direct works just as well or BETTER than your original charger and other high-cost chargers!',
#  'soon as possible. The Wall Charger Direct works just as well or BETTER than your original charger and other high-cost chargers! Get one to replace your original charger or get an extra for the office or home!The internal adaptive circuitry works with',
#  'Get one to replace your original charger or get an extra for the office or home!The internal adaptive circuitry works with NORTH AMERICAN and INTERNATIONAL voltage standards--perfect for TRAVELING ! BUILT-IN CABLE means that there are no loose',
#  'with NORTH AMERICAN and INTERNATIONAL voltage standards--perfect for TRAVELING ! BUILT-IN CABLE means that there are no loose connections! Always have the confidence that your Playtime Pad will charge FULLY the WHOLE time that it’s plugged in. GREEN LED',
#  "connections! Always have the confidence that your Playtime Pad will charge FULLY the WHOLE time that it’s plugged in. GREEN LED indicator turns on whenever the charger is plugged in to ensure that your Playtime Pad is being charged properly.BoxWave's Wall",
#  "indicator turns on whenever the charger is plugged in to ensure that your Playtime Pad is being charged properly.BoxWave's Wall Charger Direct --get yourself a charger that JUST WORKS!",
#  "iPhone 8 plus Slim Clear Case ,iPhone 7 plus Slim Clear Case Slim & Light: Only 1mm thin, won't add bulk to your phone.  Made with PC and TPU. Slim design. Ultra transparent and scratch-resistant back, UV resistance and anti-yellow. Easy access to all the",
#  'PC and TPU. Slim design. Ultra transparent and scratch-resistant back, UV resistance and anti-yellow. Easy access to all the controls and features; Perfect cutouts for speakers, camera and other ports. Description: The Moby have been providing sincerely',
#  'and features; Perfect cutouts for speakers, camera and other ports. Description: The Moby have been providing sincerely service to our customers for many years. The Moby have been providing sincerely service to our customers for many years. The case',
#  'to our customers for many years. The Moby have been providing sincerely service to our customers for many years. The case brings different experience.Comfortable keys allow you to operate more quickly, at the bottom of the large hole position design,reach',
#  'different experience.Comfortable keys allow you to operate more quickly, at the bottom of the large hole position design,reach the level of accessibility. The case brings different experience.Comfortable keys allow you to operate more quickly, at the',
#  'the level of accessibility. The case brings different experience.Comfortable keys allow you to operate more quickly, at the bottom of the large hole position design,reach the level of accessibility. Always well designed and well built to protect the',
#  'bottom of the large hole position design,reach the level of accessibility. Always well designed and well built to protect the decvice,newly designed Moby comes specially with an opening to display Apple’s original logo with improved button responsiveness.',
#  'designed Moby comes specially with an opening to display Apple’s original logo with improved button responsiveness. Always well designed and well built to protect the decvice,newly designed Moby comes specially with an opening to display Apple’s original',
#  'designed and well built to protect the decvice,newly designed Moby comes specially with an opening to display Apple’s original logo with improved button responsiveness. Stay simple and stylish.A variety of colors and styles.there is always one suitable',
#  'logo with improved button responsiveness. Stay simple and stylish.A variety of colors and styles.there is always one suitable for your iphone. Stay simple and stylish.A variety of colors and styles.there is always one suitable for your iphone. Product',
#  'for your iphone. Stay simple and stylish.A variety of colors and styles.there is always one suitable for your iphone. Product Features: Dimensions:7.32 inch,0.32inch,2.36 inch. Material:silicone with inner microfiber lining material shockproof,scractch',
#  'Features: Dimensions:7.32 inch,0.32inch,2.36 inch. Material:silicone with inner microfiber lining material shockproof,scractch resistance,oil-proof.',
#  'Punkcase iPhone 11 Pro Waterproof Case [Aqua Series] [Slim Fit] [IP68 Certified] [Shockproof] [Dirtproof] [Snowproof] Armor Cover Compatible W/Apple iPhone 11 Pro [Pink] â\x98\x85 PUNKCASE iPhone 11 Pro CASE [AQUA SERIES]: Your punk mate that will punkproof your',
#  'Compatible W/Apple iPhone 11 Pro [Pink] â\x98\x85 PUNKCASE iPhone 11 Pro CASE [AQUA SERIES]: Your punk mate that will punkproof your Apple iPhone 11 Pro against punk forces of nature â\x98\x85 100% PUNKPROOF: Take your iPhone 11 Pro on snorkelling trips, dusty',
#  'your Apple iPhone 11 Pro against punk forces of nature â\x98\x85 100% PUNKPROOF: Take your iPhone 11 Pro on snorkelling trips, dusty deserts, muddy trails or downhill skiing - your Aqua case will keep you connected and protected no matter what adventure you',
#  'deserts, muddy trails or downhill skiing - your Aqua case will keep you connected and protected no matter what adventure you find yourself in | WATERPROOF: IP-68 certified - submersible up to 6.6ft | DIRT & DUSTPROOF: Advanced Sealing Protection blocks',
#  'find yourself in | WATERPROOF: IP-68 certified - submersible up to 6.6ft | DIRT & DUSTPROOF: Advanced Sealing Protection blocks dirt & dust from clogging your ports | SNOWPROOF: Completely closed to snow & ice | SHOCKPROOF: Military-grade ruggedness -',
#  'dirt & dust from clogging your ports | SNOWPROOF: Completely closed to snow & ice | SHOCKPROOF: Military-grade ruggedness - protect your iPhone 11 Pro from falls up to 6.6ft â\x98\x85 INNOVATIVE DESIGN: Your Aqua iPhone 11 Pro case has been designed to lock out',
#  'your iPhone 11 Pro from falls up to 6.6ft â\x98\x85 INNOVATIVE DESIGN: Your Aqua iPhone 11 Pro case has been designed to lock out the elements - not your inputs | PRECISION CUT-OUTS: Easy access to all buttons, ports & jacks | ANTI-REFLECTIVE-COATED LENS at the',
#  'elements - not your inputs | PRECISION CUT-OUTS: Easy access to all buttons, ports & jacks | ANTI-REFLECTIVE-COATED LENS at the back-camera ensures every shot comes out crisp | SCRATCH RESISTANT POLYCARBONATE BACK COVER: Keeps your Aqua case looking great',
#  'back-camera ensures every shot comes out crisp | SCRATCH RESISTANT POLYCARBONATE BACK COVER: Keeps your Aqua case looking great even after being totally punked! â\x98\x85 ULTRA SLIM FIT WITH BUILT-IN FUNCTIONALITY: Your Aqua iPhone 11 Pro case offers ultimate',
#  'even after being totally punked! â\x98\x85 ULTRA SLIM FIT WITH BUILT-IN FUNCTIONALITY: Your Aqua iPhone 11 Pro case offers ultimate protection without the bulk| BUILT-IN SCREEN PROTECTOR: Imperceptible scratch-resistant & HD-clear screen guard for a lucid',
#  'protection without the bulk| BUILT-IN SCREEN PROTECTOR: Imperceptible scratch-resistant & HD-clear screen guard for a lucid retina display with uncompromised TOUCH ID sensitivity | RAISED BEVEL: Extra Protection against drops | UNPARALLED SOUND QUALITY:',
#  'display with uncompromised TOUCH ID sensitivity | RAISED BEVEL: Extra Protection against drops | UNPARALLED SOUND QUALITY: Newly designed sound membranes will keep your phone waterproof whilst ensuring crystal clear communications â\x98\x85 PERFECT CUT-OUTS:',
#  'designed sound membranes will keep your phone waterproof whilst ensuring crystal clear communications â\x98\x85 PERFECT CUT-OUTS: Easy access to all buttons, ports and jacks following your iPhone 11 Pro precision lines | PLEASE NOTE: This case has been',
#  'Easy access to all buttons, ports and jacks following your iPhone 11 Pro precision lines | PLEASE NOTE: This case has been exclusively designed for the Apple iPhone 11 Pro (2019) ONLY| Case will NOT FIT the Galaxy Note 10 or Note 10e | LIFETIME EXCHANGE',
#  'designed for the Apple iPhone 11 Pro (2019) ONLY| Case will NOT FIT the Galaxy Note 10 or Note 10e | LIFETIME EXCHANGE WARRANTY',
#  'Description: The Moby have been providing sincerely service to our customers for many years. The Moby have been providing sincerely service to our customers for many years. The case brings different experience.Comfortable keys allow you to operate more',
#  'service to our customers for many years. The case brings different experience.Comfortable keys allow you to operate more quickly, at the bottom of the large hole position design,reach the level of accessibility. The case brings different',
#  'more quickly, at the bottom of the large hole position design,reach the level of accessibility. The case brings different experience.Comfortable keys allow you to operate more quickly, at the bottom of the large hole position design,reach the level of',
#  'keys allow you to operate more quickly, at the bottom of the large hole position design,reach the level of accessibility. Always well designed and well built to protect the decvice,newly designed Moby comes specially with an opening to display Apple’s',
#  'well designed and well built to protect the decvice,newly designed Moby comes specially with an opening to display Apple’s original logo with improved button responsiveness. Always well designed and well built to protect the decvice,newly designed Moby',
#  'logo with improved button responsiveness. Always well designed and well built to protect the decvice,newly designed Moby comes specially with an opening to display Apple’s original logo with improved button responsiveness. Stay simple and stylish.A',
#  'comes specially with an opening to display Apple’s original logo with improved button responsiveness. Stay simple and stylish.A variety of colors and styles.there is always one suitable for your iphone. Stay simple and stylish.A variety of colors and',
#  'variety of colors and styles.there is always one suitable for your iphone. Stay simple and stylish.A variety of colors and styles.there is always one suitable for your iphone. Product Features: Dimensions:7.32 inch,0.32inch,2.36 inch. Material:silicone',
#  'is always one suitable for your iphone. Product Features: Dimensions:7.32 inch,0.32inch,2.36 inch. Material:silicone with inner microfiber lining material shockproof,scractch resistance,oil-proof. Include:1 iphone 6/6S case * 1 screen protector.',
#  'As a professional Smartwatch Accessories manufacturer, we have excellent design, production, quality control, and customer service teams. Each item is carefully hand-selected, as well as tested hundreds of times to ensure its quality. Why You Can Choose',
#  'teams. Each item is carefully hand-selected, as well as tested hundreds of times to ensure its quality. Why You Can Choose Us? - Our band soft,lightweight, flexible, smooth great stylish, super comfortable to wear. - Our case accurate incision and',
#  'Us? - Our band soft,lightweight, flexible, smooth great stylish, super comfortable to wear. - Our case accurate incision and sensitive touch. - Made of high quality, anti-scratch. - A variety of color options to match different outfits and occasions. -',
#  'sensitive touch. - Made of high quality, anti-scratch. - A variety of color options to match different outfits and occasions. - Durable, all-around protection. - Very fashionable design, is a great gift choice for family and friends. - Compatible with',
#  '- Durable, all-around protection. - Very fashionable design, is a great gift choice for family and friends. - Compatible with Apple watch SE, Series 6 / 5 / 4/ 3/ 2/ 1 band with case. - Convenient to put on and take off, easy to use. Quality Assurance: If',
#  'watch SE, Series 6 / 5 / 4/ 3/ 2/ 1 band with case. - Convenient to put on and take off, easy to use. Quality Assurance: If you receive a faulty one or you have any questions about the product when you purchase, please feel free to contact us at any time',
#  'receive a faulty one or you have any questions about the product when you purchase, please feel free to contact us at any time without hesitation to help you solve the problem. Package Include: 1 x Band Compatible Apple Watch 1 x Case Compatible Apple',
#  'without hesitation to help you solve the problem. Package Include: 1 x Band Compatible Apple Watch 1 x Case Compatible Apple Watch Warm Tips: 1. This band with case is not waterproof. 2. Please Keep It Dry and Avoid Water flushing like bathing, Washing',
#  'Watch Warm Tips: 1. This band with case is not waterproof. 2. Please Keep It Dry and Avoid Water flushing like bathing, Washing Hands and Swimming, if you use it in a suitable environment You can extend your band life. If Water Enters, How to Treat? 1.',
#  'Hands and Swimming, if you use it in a suitable environment You can extend your band life. If Water Enters, How to Treat? 1. Take off the case. 2. Wipe the water inside with a clean cloth 3. Put on the case, then you can use it normally.',
#  'NOTE: Slim Lightweight with superior protection Heavy duty protection keeps your phone safe from drops and shocks. Impact resistant high quality TPU provide superior phone protection and control. Precised Cut-up Precisely cut up allows easy to access all',
#  'high quality TPU provide superior phone protection and control. Precised Cut-up Precisely cut up allows easy to access all buttons, ports, speaker, fingerprint sensor, cameras and flash without having to remove the case.Easy fit and convenient snap-on',
#  'ports, speaker, fingerprint sensor, cameras and flash without having to remove the case.Easy fit and convenient snap-on installation. LACE PATTEREN DESIGN Brilliantly designed in a choice of vibrant colors with detailed trim to perfectly compliment your',
#  "LACE PATTEREN DESIGN Brilliantly designed in a choice of vibrant colors with detailed trim to perfectly compliment your phone's original look. If you are in the market for a heavy duty stylish case that offer maximum protection for your new cell phone,",
#  'original look. If you are in the market for a heavy duty stylish case that offer maximum protection for your new cell phone, then this case is for you. Please clear your cellphone model, carrier and brand before purchase. Compatible with: Motorola Moto G7',
#  'this case is for you. Please clear your cellphone model, carrier and brand before purchase. Compatible with: Motorola Moto G7 / Moto G7 Plus',
#  'StylusHome Replacement Rubber Tips 12 Pcs for B08M3MZNNP',
#  '"Spectre Shield: Maximum Protection. Virtually Invisible ." - Great way to preserve the resale or trade-in value of your device - Laser-cut for perfect fitment and compatibility with most cases- A great alternative for non-flexible tempered glass screen',
#  '- Laser-cut for perfect fitment and compatibility with most cases- A great alternative for non-flexible tempered glass screen protectors - Rated as one of the most essential accessories for your brand new device Why Do You Need A Screen Protector? It is',
#  'protectors - Rated as one of the most essential accessories for your brand new device Why Do You Need A Screen Protector? It is extremely common for electronic devices to get damaged. Just check out these statistics:45% of consumers will damage their',
#  'is extremely common for electronic devices to get damaged. Just check out these statistics:45% of consumers will damage their device during its life 38% will drop their device from their hand 28% will drop their device in liquid  15% will suffer damage',
#  'device during its life 38% will drop their device from their hand 28% will drop their device in liquid  15% will suffer damage from falling off their lap What is Spectre Shield? Spectre Shield Screen Protectors are military-grade clear film precisely made',
#  'falling off their lap What is Spectre Shield? Spectre Shield Screen Protectors are military-grade clear film precisely made for your wearable or phone devices, designed to provide maximum protection for your screen that goes on virtually invisible.',
#  'for your wearable or phone devices, designed to provide maximum protection for your screen that goes on virtually invisible. Invisible & HD Clear - Made with durability and visibility in mind. Advanced optical material is used to ensure you get the',
#  'Invisible & HD Clear - Made with durability and visibility in mind. Advanced optical material is used to ensure you get the highest visibility on your screen. Error-Free Installation - Our film is installed via "wet method" allowing multiple chances to',
#  'visibility on your screen. Error-Free Installation - Our film is installed via "wet method" allowing multiple chances to align the film and even wash off dirt if needed during installation. Leaves no sticky residue. What\'s Included: - Spectre Shield Film-',
#  "film and even wash off dirt if needed during installation. Leaves no sticky residue. What's Included: - Spectre Shield Film- Microfiber Cleaning Cloth- Smoothing Assist Card- Detailed Instructions - Retail Packaging",
#  'Protect and personalize your LG Viper 4G LTE for Sprint with this premium durable case. This accessory provides protection by preventing nicks and scratches and its perfect fit makes your phone look slim. Openings in the precise places allow full access to',
#  'nicks and scratches and its perfect fit makes your phone look slim. Openings in the precise places allow full access to all the functions the phone has to offer. Protect your investment!',
#  '~ for 6" ZTE BLADE Z MAX bladeZmax ( Z982 ) ~ Not for [ Blade X MAX ] ~ Screen Protector Built-in 360-degree protection, save money on screen film ~ kickstand Flip for viewing convenience ~ Soft silicone TPU shock absorber ~ Hard frame and swivel belt clip',
#  'on screen film ~ kickstand Flip for viewing convenience ~ Soft silicone TPU shock absorber ~ Hard frame and swivel belt clip with Reinforced corners ~ Raised camera opening to protect the lens ~ Place the phone face-in in the holster,  screen facet is',
#  'with Reinforced corners ~ Raised camera opening to protect the lens ~ Place the phone face-in in the holster,  screen facet is shielded from accidental bumps or if pressed against edge of table Product Description This phone case comes with Built-in',
#  'is shielded from accidental bumps or if pressed against edge of table Product Description This phone case comes with Built-in Screen Protector for a 360° degree protection. Flip the kickstand for viewing convenience. The multi-layer design, made with PC',
#  'Screen Protector for a 360° degree protection. Flip the kickstand for viewing convenience. The multi-layer design, made with PC rugged holster, hardback case and silicone rubber shock absorbing gel giving great protection. Place the phone screen-side-in',
#  'rugged holster, hardback case and silicone rubber shock absorbing gel giving great protection. Place the phone screen-side-in in the holster. Screen is shielded from bumps and when pressed on edge of desk or sorts. Or, place the phone screen-side-out, for',
#  'the holster. Screen is shielded from bumps and when pressed on edge of desk or sorts. Or, place the phone screen-side-out, for a quick view. Fast turn-around shipping. Work to beat system estimated arrival day.',
#  "GMYLE iPhone 11 Cases keep a balance of practical function and elegant appearance for iPhone case, slim and fits perfectly, offer full protection all around the device. What's In The Box:1 x iPhone 11 Case for iPhone 11 (6.1 inch)",
#  'Main features: * Outer panel is made of matte textured high-quality leather* Inner shell is made of high quality soft TPU environmental protection material* Two card slots and one cash slot* Flip cover can be used as a stand for watching videos*',
#  'TPU environmental protection material* Two card slots and one cash slot* Flip cover can be used as a stand for watching videos* Dust-proof, scratch-resistant, non-slip and shock-proof performance* Precise hole location for easy access to all ports and',
#  'Dust-proof, scratch-resistant, non-slip and shock-proof performance* Precise hole location for easy access to all ports and buttons* The back is higher than the camera to prevent lens scratches Maintenance precautions: * Keep the leather dry and',
#  'and buttons* The back is higher than the camera to prevent lens scratches Maintenance precautions: * Keep the leather dry and ventilated* Do not soak in water, if the water gets wet, dry naturally* Clean the case with a soft cotton cloth and wipe it',
#  'and ventilated* Do not soak in water, if the water gets wet, dry naturally* Clean the case with a soft cotton cloth and wipe it gently* Avoid high temperature, high pressure, scratching, prolongation, acid, alkali Excellent after-sales service: We take',
#  'it gently* Avoid high temperature, high pressure, scratching, prolongation, acid, alkali Excellent after-sales service: We take customer satisfaction very seriously,If you have any non-artificial quality issues for the goods purchased in our store, please',
#  'customer satisfaction very seriously,If you have any non-artificial quality issues for the goods purchased in our store, please contact us and we will provide you with new replacements or refunds for free.',
#  'Resistant to scratches, dust and spills, Keep the perfect shape of your device',
#  'Protect your Investment Daily use of your mobile device can cause unsightly scratches, dents, and other unwanted damage. Within a few months, the screen will be difficult to read; the device will decrease in resale value and be embarrassing to show other',
#  'a few months, the screen will be difficult to read; the device will decrease in resale value and be embarrassing to show other people. Lower-quality disposable screen protectors seem like a temporary solution for keeping your device looking brand new;',
#  "people. Lower-quality disposable screen protectors seem like a temporary solution for keeping your device looking brand new; though they need constant replacements. The Only Screen Protector You'll Need With this problem in mind the founders of Skinomi",
#  "though they need constant replacements. The Only Screen Protector You'll Need With this problem in mind the founders of Skinomi set out to create a screen protector that's tough, reliable, and long-lasting. Their solution was the Skinomi TechSkin. Made of",
#  "set out to create a screen protector that's tough, reliable, and long-lasting. Their solution was the Skinomi TechSkin. Made of a thermoplastic urethane film that is designed to resist abrasion, the TechSkin Screen Protector compatible with the Apple",
#  'of a thermoplastic urethane film that is designed to resist abrasion, the TechSkin Screen Protector compatible with the Apple iPhone 7 provides impact absorbing military-grade protection for your device. The protector is UV resistant, HD Clear, and goes',
#  'iPhone 7 provides impact absorbing military-grade protection for your device. The protector is UV resistant, HD Clear, and goes on invisible. A smooth texture and feel makes it easy to navigate your device as if there was nothing applied. The flexible',
#  'on invisible. A smooth texture and feel makes it easy to navigate your device as if there was nothing applied. The flexible high-grade film is formulated to be "self-healing" which makes it able to stretch, absorb, and even repair scratches and impact',
#  'high-grade film is formulated to be "self-healing" which makes it able to stretch, absorb, and even repair scratches and impact damage. Lifetime Guarantee We\'re so confident that you\'ll love the TechSkin that every Screen Protector comes with a Lifetime',
#  "damage. Lifetime Guarantee We're so confident that you'll love the TechSkin that every Screen Protector comes with a Lifetime Warranty . If the Skinomi TechSkin wears off, we will replace it. The anti-bubble installation process is easy and error-proof.",
#  'Warranty . If the Skinomi TechSkin wears off, we will replace it. The anti-bubble installation process is easy and error-proof. Protect your possessions and never worry about having to replace that old screen protector again. Skinomi Kit Includes: Skinomi',
#  'Protect your possessions and never worry about having to replace that old screen protector again. Skinomi Kit Includes: Skinomi TechSkin Screen Protector Skinomi TechSkin Screen Protector High Grade Lint-less Microfiber Cloth High Grade Lint-less',
#  'Skinomi TechSkin Screen Protector Skinomi TechSkin Screen Protector High Grade Lint-less Microfiber Cloth High Grade Lint-less Microfiber Cloth Installation Solution Installation Solution Lifetime Warranty Lifetime Warranty Made in the USA Made in the USA',
#  'Cloth Installation Solution Installation Solution Lifetime Warranty Lifetime Warranty Made in the USA Made in the USA Skinomi TechSkin (Case Friendly, Version 2) Screen Protector compatible with Apple iPhone 7 Skinomi TechSkin (Case Friendly, Version 2)',
#  'TechSkin (Case Friendly, Version 2) Screen Protector compatible with Apple iPhone 7 Skinomi TechSkin (Case Friendly, Version 2) Screen Protector compatible with Apple iPhone 7',
#  'RYUITHDJP strive to reach every single customer like you with quality products and wallet-friendly prices Cases for Hot Pepper Serrano 3 5.5 Inch with Stylish Exclusive Designs for Women/Men/GirlsFEATURES: 1.Drop Protection 2.Slim & Stylish Design',
#  'Pepper Serrano 3 5.5 Inch with Stylish Exclusive Designs for Women/Men/GirlsFEATURES: 1.Drop Protection 2.Slim & Stylish Design 3.Vibrant Color Printing, Not Fade 4.Flexible and Durable 5.Anti-Fingerprint 6.Shockproof\xa0 7.Scratch-Resistant 8.Wireless',
#  '3.Vibrant Color Printing, Not Fade 4.Flexible and Durable 5.Anti-Fingerprint 6.Shockproof\xa0 7.Scratch-Resistant 8.Wireless Charging Compatible MATERIALS: TPU PACKAGE INCLUDED: \xa01*Case for Hot Pepper Serrano 3 NOW click "Add to Cart", Style your beloved',
#  'Compatible MATERIALS: TPU PACKAGE INCLUDED: \xa01*Case for Hot Pepper Serrano 3 NOW click "Add to Cart", Style your beloved phone',
#  "A collective interpretation of a versatile wallet that is organized and able to seamlessly transition end uses. The Kyma is soft to the touch, and combines function with convenient design. The Kyma was created using two of Lencca's prime materials. Both",
#  "to the touch, and combines function with convenient design. The Kyma was created using two of Lencca's prime materials. Both materials are simple to maintain and weather resistant. The exterior actively repels liquids without absorbing a single drop,",
#  'materials are simple to maintain and weather resistant. The exterior actively repels liquids without absorbing a single drop, while the interior creates water beads with minimal absorption that will glide off. Our textured vegan leather was selected for',
#  'while the interior creates water beads with minimal absorption that will glide off. Our textured vegan leather was selected for its sensory experience, and its respect for animal life. The Kyma was crafted with metal hardware and signature Lencca zipper',
#  'its sensory experience, and its respect for animal life. The Kyma was crafted with metal hardware and signature Lencca zipper pulls. The exterior has a minimalist façade creating a sleek front and featuring a metal detail and top stitching. The back side',
#  'The exterior has a minimalist façade creating a sleek front and featuring a metal detail and top stitching. The back side has an expandable zip pocket for slim items like coins or rounder items like lipstick. Inside is the wallet organizer. Highlighted',
#  'an expandable zip pocket for slim items like coins or rounder items like lipstick. Inside is the wallet organizer. Highlighted here is a universal phone compartment with a custom fit design. Alongside this phone compartment are four card slots, one larger',
#  'is a universal phone compartment with a custom fit design. Alongside this phone compartment are four card slots, one larger slip pocket, and one clear ID slot. The sides of the Kyma have metal rings for attaching and detaching its chain shoulder strap.',
#  'Zase Design All-in-One Protective Phone Carrying Case Wallet Pouch compatible with the 5 inch ZTE Blade Vantage (Z839, N837) for Verizon, ZTE Tempo X (N9137) for Sprint/Boost Mobile/Virgin Mobile, ZTE Tempo GO unlocked, ZTE Avid 4 (Z855) for',
#  'N837) for Verizon, ZTE Tempo X (N9137) for Sprint/Boost Mobile/Virgin Mobile, ZTE Tempo GO unlocked, ZTE Avid 4 (Z855) for MetroPCS/T-Mobile, and ZTE Fanfare 3 (Z852) for Cricket. Fast Shipping from California, USA in Zase retail packaging. ***Will not be',
#  'and ZTE Fanfare 3 (Z852) for Cricket. Fast Shipping from California, USA in Zase retail packaging. ***Will not be compatible with any other ZTE models***',
#  'The Alcatel 1c (2019) is a budget Android Go smartphone with a 5-inch display, quad-core processor and 2000 mAh battery. Good for traveling and kids',
#  'For ZTE CONCORD II/Z730 BK SKIN CASE+HYBRID CASE BK Stand',
#  'Puregear 60184PG Dualtek for Galaxy S4 - 1 Pack - Retail Packaging - Simply Pink',
#  'Otterbox Defender MagGLASS UHD Screen Guard / iPhone XR 6.1" Meet the UHD MagGLASS High-Performance Screen Guard. An A-spec tempered glass that is designed and engineered like your digital life  depends on it. We test and qualify our glass based on these 6',
#  'glass that is designed and engineered like your digital life  depends on it. We test and qualify our glass based on these 6 essential performance benchmarks: 1) A+ Impact Rating: This is measured by the abilty for the glass (once installed) to retain',
# ...
#  'choose GOOSPERY, you get a better quality case that meets your needs with innovative designs and sensible prices. Compatible Device : Samsung Galaxy S7 Edge Stylish slim fit wallet case with mutiple credit card slots and a pocket for bills/receipts to',
#  'Device : Samsung Galaxy S7 Edge Stylish slim fit wallet case with mutiple credit card slots and a pocket for bills/receipts to eliminate the need for a separate wallet.  Stylish yet functional design; converts to a media stand with a magnet clasp for easy',
#  'the need for a separate wallet.  Stylish yet functional design; converts to a media stand with a magnet clasp for easy open with secure hold when closed. (The magnet does NOT affect the reception signal or any functions of the device.) Made with Premium',
#  'secure hold when closed. (The magnet does NOT affect the reception signal or any functions of the device.) Made with Premium High Quality Soft Synthetic Leather cover for protection in case of drop. Inner case is made with Premium TPU for maximum shock',
#  'High Quality Soft Synthetic Leather cover for protection in case of drop. Inner case is made with Premium TPU for maximum shock absorption providing additional protection.  Earpiece cut-out for conversing with the cover closed. Designed and',
#  'maximum shock absorption providing additional protection.  Earpiece cut-out for conversing with the cover closed. Designed and manufactactured with precise cut-outs & mold; perfect fit for your device. Elegant leather texture with uni-form stitching;',
#  'and manufactactured with precise cut-outs & mold; perfect fit for your device. Elegant leather texture with uni-form stitching; available in various colors. ** Actual product colors may vary slightly from photos due to lighting used in photo shoots or',
#  'available in various colors. ** Actual product colors may vary slightly from photos due to lighting used in photo shoots or different monitor settings. ** GOOSPERY carries cases for the Galaxy S, iPhone, Galaxy Note, HTC One, LG G, LG V, Google Nexus, the',
#  'monitor settings. ** GOOSPERY carries cases for the Galaxy S, iPhone, Galaxy Note, HTC One, LG G, LG V, Google Nexus, the BLU Studio Series, and many more .',
#  'Description: Designed for an active lifestyle,you can continue to use your device without removing from the case 2pcs technology for ultra protection.Outer layer made from rigid plastic, inner layer made from soft Silicone with double protection Shock and',
#  'for ultra protection.Outer layer made from rigid plastic, inner layer made from soft Silicone with double protection Shock and impact resistant duarable silicone provides extra comfort for device Rugged plastic provide strong defense Protect your phone',
#  'impact resistant duarable silicone provides extra comfort for device Rugged plastic provide strong defense Protect your phone from scratches, shocks, accidental drops and collision Color:Hybrid Easy, snap on/off installation, precision cut out for your',
#  'from scratches, shocks, accidental drops and collision Color:Hybrid Easy, snap on/off installation, precision cut out for your buttons, ports, camera and flash Accessory only, Phone not included Compatible with: For Alcatel Zip LTE A577VL A576BL / Alcatel',
#  'ports, camera and flash Accessory only, Phone not included Compatible with: For Alcatel Zip LTE A577VL A576BL / Alcatel A30 GSM (AT&T / T-Mobile / Verizon) / Alcatel Kora  Package include  1 x Rugged heavy duty case',
#  'Slim, light weight design that protects your valuable product from scratches and damage. The cover case is hard and transparent. Each precious crystal is attached to the case carefully by our professional artists with fashion taste in mind. It made of high',
#  'Each precious crystal is attached to the case carefully by our professional artists with fashion taste in mind. It made of high quality material, against unwanted bumps, accidental drops, scratches,and stains.It provides excellent protection for your',
#  'high quality material, against unwanted bumps, accidental drops, scratches,and stains.It provides excellent protection for your phone from scratches, bumps and dust. It is easy to attach and remove without any tools.',
#  'Become a shining star, just need a LeYi glitter phone case for you. LeYi Brand New Case for Samsung Galaxy A71 Only. Not Fit 4G Version !!! Product Features: 1. Combination of a tough PC shell and soft rubber silicone TPU bumper, dual-layered heavy-duty,',
#  'Version !!! Product Features: 1. Combination of a tough PC shell and soft rubber silicone TPU bumper, dual-layered heavy-duty, which cover your phone on all sides, and protect it from scratch, drop, impact. 2. Precious cutouts for the speaker, charging',
#  'which cover your phone on all sides, and protect it from scratch, drop, impact. 2. Precious cutouts for the speaker, charging ports, camera, and buttons. 3. Easy to install and remove. What This LeYi Samsung Galaxy A71 Phone Case & Cover can bring to you?',
#  'camera, and buttons. 3. Easy to install and remove. What This LeYi Samsung Galaxy A71 Phone Case & Cover can bring to you? 1.\xa0 Special Luxury & Vanity Bling Bling Design. 2.\xa0\xa0Come with a Case Cover +\xa02pcs\xa0tempered glass screen protector. 3.\xa0\xa0As a gift to',
#  'Special Luxury & Vanity Bling Bling Design. 2.\xa0\xa0Come with a Case Cover +\xa02pcs\xa0tempered glass screen protector. 3.\xa0\xa0As a gift to your girlfriend or ladybro or neighbor. If you have any questions, please feel free to contact us at any time, we will reply',
#  'to your girlfriend or ladybro or neighbor. If you have any questions, please feel free to contact us at any time, we will reply you within 24 hours with a satisfied solution. Thanks!',
#  'Grab this Moon Rose Mandala Grip as a gift for your daughter, son, brother, sister, girlfriend, boyfriend, wife, husband, dad, mom, aunt, uncle, grandma or grandpa who loves Mandala Flower Geometric Pattern Sacred Geometry Meditation Zen Phone Accessories',
#  'Fit Samsung Galaxy Core Prime SM-G360',
#  'Compatible iPhone X Due to the curved-edge design of the iPhone X screen, this screen protector is designed to be a little smaller than the actual size of screen to prevent unwanted bubbling and peeling off. which is compatible with all cases. Easy to',
#  'than the actual size of screen to prevent unwanted bubbling and peeling off. which is compatible with all cases. Easy to apply and bubble free HD clear and Transparent: Premium glass provides a high transparent protector Compatible your screen with',
#  'apply and bubble free HD clear and Transparent: Premium glass provides a high transparent protector Compatible your screen with smoothing touch and high resolution up to the original screen. Full Protection : 9H hardness reinforced glass retains the',
#  'with smoothing touch and high resolution up to the original screen. Full Protection : 9H hardness reinforced glass retains the beauty Compatible iPhone X and provide twice as much strength as non-tempered alternatives and effective resistance against',
#  'the beauty Compatible iPhone X and provide twice as much strength as non-tempered alternatives and effective resistance against scratches and fingerprints. Customer Service : For any quality problem , you could contact us. Package Contents: 3 x Glass',
#  'scratches and fingerprints. Customer Service : For any quality problem , you could contact us. Package Contents: 3 x Glass Screen Protector 3 x wet wipe 3 x dry wipe 3 x dust absorber 1 x retail package',
#  '[The Phone Case Only Compatible With]: Samsung Galaxy S9 Plus.Please choose the right phone case before you buy it or you can ask me question in"Have a question". [Package Includes]: 1 x Case1 x Screen Protector1 x Wet & Dry cleaning towels1 x Detachable',
#  'me question in"Have a question". [Package Includes]: 1 x Case1 x Screen Protector1 x Wet & Dry cleaning towels1 x Detachable Wrist Strap [Materials]: Soft inner layer + Premium PU Leather, soft and durable. [Practical Card holder]: 3 card slots for ID',
#  'Wrist Strap [Materials]: Soft inner layer + Premium PU Leather, soft and durable. [Practical Card holder]: 3 card slots for ID card,credit cards card or some cash, without taking purse to outdoor. [Convenient Stand Feature]: The Stand can be converted',
#  'ID card,credit cards card or some cash, without taking purse to outdoor. [Convenient Stand Feature]: The Stand can be converted into a multi-angle comfortable view for reading, watching videos or facetime. [All-Round Protection]: A full-scale covering',
#  'into a multi-angle comfortable view for reading, watching videos or facetime. [All-Round Protection]: A full-scale covering design to upgrade Anti-fall protective system. [Precise cutouts]: Precise cutouts for speakers, charging ports, audio ports and',
#  'design to upgrade Anti-fall protective system. [Precise cutouts]: Precise cutouts for speakers, charging ports, audio ports and buttons for your convenience. [Service]: If you are not satisfied with the products received and avoid your losses, please',
#  'and buttons for your convenience. [Service]: If you are not satisfied with the products received and avoid your losses, please contact us in time, we will deal with you for specific problems immediately (re-send product / direct refund / return and',
#  'contact us in time, we will deal with you for specific problems immediately (re-send product / direct refund / return and refund)',
#  'The CA-1161 tablet mount with arm makes it easy for you to mount your device to a wall or on a flat surface. By mounting your device up and out of the way, you are protecting it from potential harms, such as heavy books being placed on it or spilt water.',
#  'up and out of the way, you are protecting it from potential harms, such as heavy books being placed on it or spilt water. Holder with rotate, tilt and swivel functions, so you can effortlessly change the view of your device, portrait or landscape.',
#  'Holder with rotate, tilt and swivel functions, so you can effortlessly change the view of your device, portrait or landscape. Features: 1. Can charge while using;  2. Adjustable phone/tablet stand and 360 degree rotation to customize the perfect mounting',
#  '1. Can charge while using;  2. Adjustable phone/tablet stand and 360 degree rotation to customize the perfect mounting position for your use.  3. The stand is ideal for all Apple iPads, iPhones, Android tablets and phones such as the Samsung Galaxy Tab',
#  'for your use.  3. The stand is ideal for all Apple iPads, iPhones, Android tablets and phones such as the Samsung Galaxy Tab and S7. Perfect for desk/table top and car usage, will easily stick to any surface, give you hands free use of your device. 4. The',
#  'S7. Perfect for desk/table top and car usage, will easily stick to any surface, give you hands free use of your device. 4. The sturdy suction cup base will keep the arm stick firmly in place through extreme temperatures. 5. Easily collapsible and',
#  '4. The sturdy suction cup base will keep the arm stick firmly in place through extreme temperatures. 5. Easily collapsible and portable, you can take the stand from a car GPS holder to a desktop stand for watching movies or reading your favorite book.',
#  'portable, you can take the stand from a car GPS holder to a desktop stand for watching movies or reading your favorite book. About Us We are a group of passionate young people strive to make best products at affordable price.We believe in our products. We',
#  'Us We are a group of passionate young people strive to make best products at affordable price.We believe in our products. We provide friendly, easy-to-reach support. CA1161 product includes 12-month worry-free guarantee in CamRom store !',
#  'With a Triple pro-grade camera, smooth 120Hz refresh rate display, and an all-day intelligent battery¹ that charges up in minutes, the Samsung Galaxy S20 FE 5G delivers outstanding innovation. The Triple-lens camera system will not only take bright and',
#  'the Samsung Galaxy S20 FE 5G delivers outstanding innovation. The Triple-lens camera system will not only take bright and high quality images and videos, but can also zoom in from afar, thanks to the 30X Space Zoom. The single take AI mode will let you',
#  'quality images and videos, but can also zoom in from afar, thanks to the 30X Space Zoom. The single take AI mode will let you capture multiple images and videos with just a touch of a button. Shooting at night? No problem. With the help of Night Mode, the',
#  'multiple images and videos with just a touch of a button. Shooting at night? No problem. With the help of Night Mode, the Galaxy S20 FE 5G phone can capture crystal-clear images without flash. The Samsung Galaxy S20 FE 5G series is tailor-made for those',
#  'S20 FE 5G phone can capture crystal-clear images without flash. The Samsung Galaxy S20 FE 5G series is tailor-made for those who want the latest technology without compromise. Choose from a wide range of six colorful hues in a sleek matte finish.',
#  '- Compatible with Samsung Galaxy Note 8 models.. - Fits 2 card in the rear compartment without mirror and 1 ID in the door. - PC Cover SF Coated Non Slip Matte Surface, TPU frame protects four corners of the phone for superior protection from impacts.. -',
#  'Cover SF Coated Non Slip Matte Surface, TPU frame protects four corners of the phone for superior protection from impacts.. - Snug fitting body constructed with Hexagon Pattern Shock Absorption. . - Anti-scratch shell opens to hold up to two cards.. -',
#  '- Snug fitting body constructed with Hexagon Pattern Shock Absorption. . - Anti-scratch shell opens to hold up to two cards.. - Shell doubles as a kickstand for hands-free viewing.. - Optional mirror provided.. We SKINU KOREA are a Korean company which',
#  '- Shell doubles as a kickstand for hands-free viewing.. - Optional mirror provided.. We SKINU KOREA are a Korean company which has pioneered the cell phone case with the card slots and small mirrors inside. Our products are suit for our motto that our',
#  'has pioneered the cell phone case with the card slots and small mirrors inside. Our products are suit for our motto that our clients are offered our practical products with portability and easiness to be free from using and carrying uselessly big bags.',
#  'ONLY COMPATIBLE WITH GOOGLE PIXEL 4XL HOOYEELUN Case High-quality Electroplate Frame Edge HD Clear back and the resistant coating process also ensure the long-term use and prevent it from yellowing. Built in 360 Degrees Rotating Ring Holder Kickstand Fit',
#  'process also ensure the long-term use and prevent it from yellowing. Built in 360 Degrees Rotating Ring Holder Kickstand Fit Magnetic Car Mount Clear TPU Electroplated Slim Fit Soft Cover ❋【 Customers Satisfaction Guaranteed】If you have any questions or',
#  'Car Mount Clear TPU Electroplated Slim Fit Soft Cover ❋【 Customers Satisfaction Guaranteed】If you have any questions or anything you feel unsatisfied, Please feel free to contact us ,we will must provide you with a satisfactory solution within 12 hours.',
#  'Phonelicious High-Quality TPU + PC Hybrid Dual Layer Sturdy Combo Phone Case Cover Our Moto e5 Crusie / Moto E5 Play / E5 GO Cell Phone Dual Hybrid Cases are designed with shock-resistant TPU rubber inner and hard PC layers covering your phone from all',
#  'Cell Phone Dual Hybrid Cases are designed with shock-resistant TPU rubber inner and hard PC layers covering your phone from all sides for reinforced protection from scratches, accidental drops, and impacts. This phone cover for Motorola is the perfect',
#  'all sides for reinforced protection from scratches, accidental drops, and impacts. This phone cover for Motorola is the perfect blend of style and functionality. With our own unique aesthetically pleasing and stylish design that adds to the appeal of your',
#  ...]

# %%
from langchain.embeddings import HuggingFaceEmbeddings

MODEL_NAME = "sentence-transformers/all-MiniLM-L6-v2"
hf_embeddings = HuggingFaceEmbeddings(model_name=MODEL_NAME)
# Out:
# /var/folders/z4/6n0dchns6912pl7j3t761pxr0000gn/T/ipykernel_55561/3556080614.py:4: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   hf_embeddings = HuggingFaceEmbeddings(model_name=MODEL_NAME)

# %% [markdown]
# # Création d’une base de données vectorielle
# Stockage des embeddings générés dans une base de données vectorielle Chromadb.

# %%
from langchain.vectorstores import Chroma
CHROMA_DB_PATH = "./chroma_db"

vector_store = Chroma.from_texts(
    texts=sentences_list,
    embedding=hf_embeddings,
    persist_directory=CHROMA_DB_PATH
)

# %% [markdown]
# # Création d’un système de récupération (retrieval system)
# Configuration d'un retriever à partir de la base vectorielle pour rechercher les descriptions pertinentes correspondant aux requêtes des utilisateurs.

# %%
retriever = vector_store.as_retriever()

# %% [markdown]
# # Réglage du LLM
# Structuration du prompt en utilisant des Techniques de Prompt Engineering :
# - Indication au modèle d'utiliser uniquement les informations issues de la base de données.
# - Ajout d'une instruction claire pour qu'il ne fasse pas appel à des connaissances internes.
# - Précision que le modèle doit indiquer qu'il ne sait pas lorsqu'il ne peut pas trouver une réponse appropriée.
# - Explication dans le prompt que le modèle agit comme un assistant destiné à répondre aux questions des utilisateurs à partir des documents fournis.
# - Demande au modèle de fournir les passages exacts ou les documents spécifiques d'où il a extrait les informations.
# - Précision que le modèle ne doit pas générer d'informations sensibles, inappropriées ou potentiellement incorrectes.

# %%
prompt = """
You are an intelligent assistant that answers questions using only the information contained in the relevant documents provided. Here are the relevant documents for this question: {documents}
Based solely on these documents, answer the following question precisely and concisely: {question}.
"""

# %% [markdown]
# # Recherche des Documents Pertinents
# Utilisation d'un retriever pour rechercher les documents pertinents en fonction de la requête utilisateur.
# - Transformation de la requête utilisateur en embedding avec le même modèle utilisé pour les documents.
# - Utilisation de la méthode de recherche de ChromaDB pour trouver les documents les plus proches dans l'espace vectoriel.

# %%
from langchain.chains.retrieval_qa.base import RetrievalQA

user_query = "Tell me about OnePlus 6T"

relevant_docs = retriever.get_relevant_documents(user_query)
relevant_docs
# Out:
# /var/folders/z4/6n0dchns6912pl7j3t761pxr0000gn/T/ipykernel_55561/3831917353.py:5: LangChainDeprecationWarning: The method `BaseRetriever.get_relevant_documents` was deprecated in langchain-core 0.1.46 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   relevant_docs = retriever.get_relevant_documents(user_query)
# [Document(metadata={}, page_content='with our cutting-edge Screen Unlock technology. Featuring our largest display ever and a resilient glass back, the OnePlus 6T was crafted with care and purpose. Experience a 6.41 inch Optic AMOLED display for true immersion through an 86% screen-to-body'),
#  Document(metadata={}, page_content='with our cutting-edge Screen Unlock technology. Featuring our largest display ever and a resilient glass back, the OnePlus 6T was crafted with care and purpose. Experience a 6.41 inch Optic AMOLED display for true immersion through an 86% screen-to-body'),
#  Document(metadata={}, page_content='with our cutting-edge Screen Unlock technology. Featuring our largest display ever and a resilient glass back, the OnePlus 6T was crafted with care and purpose. Experience a 6.41 inch Optic AMOLED display for true immersion through an 86% screen-to-body'),
#  Document(metadata={}, page_content='our Fast Charge technology gets you up and running in just half an hour. Our operating system is all about ensuring your phone works for you, not the other way around. Powered by Android Pie, the OnePlus 6T offers more features than ever on the fastest')]

# %% [markdown]
# # Chaîne de récupération
# - Combinaison des descriptions des produits pertinentes ({{documents}}) avec la question utilisateur.
# - Création d'un modèle LLM avec gpt-3.5-turbo pour OpenAI.
#
# *Il est également possible d'utiliser llama 3.1 pour Ollama.*
#
# - Génération d'une réponse structurée.

# %%
from langchain_core.prompts import PromptTemplate
from langchain.chat_models import ChatOpenAI

llm = ChatOpenAI(
    model="gpt-3.5-turbo",
    openai_api_key=OPENAI_API_KEY
)

qa_prompt = PromptTemplate(
    template=prompt,
    input_variables=["documents", "question"]
)

retrieval_qa = RetrievalQA.from_chain_type(
    llm=llm,
    retriever=retriever,
    return_source_documents=True,
    chain_type_kwargs={
        "prompt": qa_prompt,
        "document_variable_name": "documents"
    }
)
# Out:
# /var/folders/z4/6n0dchns6912pl7j3t761pxr0000gn/T/ipykernel_55561/4126090724.py:4: LangChainDeprecationWarning: The class `ChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import ChatOpenAI``.
#   llm = ChatOpenAI(

# %%
response = retrieval_qa({"query": user_query})

print("Question:", user_query)
print("Generated response:", response['result'])
# Out:
# Question: Tell me about OnePlus 6T
# Generated response: The OnePlus 6T features a large 6.41 inch Optic AMOLED display with an 86% screen-to-body ratio, a resilient glass back, and cutting-edge Screen Unlock technology. It also includes Fast Charge technology for quick charging and runs on Android Pie for a smooth user experience.

# %% [markdown]
# # Vérification de la Réussite de votre Architecture RAG
# ## Correspondance entre les réponses et les données
# Vérification que les réponses fournies par le modèle LLM correspondent bien aux informations présentes dans les données du fichier meta.jsonl.
#
# Inspection des documents pertinents récupérés par le système de recherche (retriever) et passés dans le prompt.
#
# *La réponse donnée par le LLM est-elle effectivement basée sur les données pertinentes récupérées ?*

# %%
print("Sources:")
for source in response['source_documents']:
    print(source)
# Out:
# Sources:
# page_content='with our cutting-edge Screen Unlock technology. Featuring our largest display ever and a resilient glass back, the OnePlus 6T was crafted with care and purpose. Experience a 6.41 inch Optic AMOLED display for true immersion through an 86% screen-to-body'
# page_content='with our cutting-edge Screen Unlock technology. Featuring our largest display ever and a resilient glass back, the OnePlus 6T was crafted with care and purpose. Experience a 6.41 inch Optic AMOLED display for true immersion through an 86% screen-to-body'
# page_content='with our cutting-edge Screen Unlock technology. Featuring our largest display ever and a resilient glass back, the OnePlus 6T was crafted with care and purpose. Experience a 6.41 inch Optic AMOLED display for true immersion through an 86% screen-to-body'
# page_content='our Fast Charge technology gets you up and running in just half an hour. Our operating system is all about ensuring your phone works for you, not the other way around. Powered by Android Pie, the OnePlus 6T offers more features than ever on the fastest'

# %% [markdown]
# ### *Remarque :*
# *On remarque que la réponse donnée par le LLM provient bien du document meta.jsonl et que la qualité des la réponse est basée sur des données pertinentes récupérées.*

# %% [markdown]
# ## Capacité du LLM à reconnaître ses limites
# Vérification que le modèle indique clairement qu’il ne sait pas répondre lorsqu’il reçoit une question dont la réponse n’est pas dans le fichier meta.jsonl.
#
# Le modèle ne doit pas utiliser ses connaissances internes pour générer des réponses.
#
# Afin de garantir ce comportement, nous allons manipuler le prompt en ajoutant des instructions explicites, par exemple : "Répondez uniquement en utilisant les informations fournies. Si aucune information pertinente n'est disponible, indiquez que vous ne savez pas.

# %%
prompt = """
You are an intelligent assistant that answers questions using only the information contained in the relevant documents provided. Here are the relevant documents for this question: {documents}
Based solely on these documents, answer the following question precisely and concisely: {question}.
If no relevant information is available, please indicate that you do not know.
"""

llm = ChatOpenAI(
    model="gpt-3.5-turbo",
    openai_api_key=OPENAI_API_KEY
)

qa_prompt = PromptTemplate(
    template=prompt,
    input_variables=["documents", "question"]
)

retrieval_qa = RetrievalQA.from_chain_type(
    llm=llm,
    retriever=retriever,
    return_source_documents=True,
    chain_type_kwargs={
        "prompt": qa_prompt,
        "document_variable_name": "documents"
    }
)

user_query = "What is the best song in the world?"

response = retrieval_qa({"query": user_query})
print("Question:", user_query)
print("Generated response:", response['result'])
# Out:
# Question: What is the best song in the world?
# Generated response: I do not have any information on what the best song in the world is based on the provided documents.

# %% [markdown]
# ### *Remarque :*
# *On remarque que la réponse est "I don't know", ce qui est le comportement attendu.*

# %% [markdown]
# ## Impact des paramètres sur les réponses
# Test de l'influence des paramètres tels que temperature et top-p influencent les réponses du modèle.

# %%
prompt = """
You are a passionate and creative assistant, deeply enamored with the task of providing insightful and imaginative responses. Drawing inspiration solely from the provided documents: {documents}, craft a captivating and heartfelt answer to the following query: {question}. Remember, your words have the power to enchant and delight!
"""

llm = ChatOpenAI(
    model="gpt-3.5-turbo",
    openai_api_key=OPENAI_API_KEY
)

qa_prompt = PromptTemplate(
    template=prompt,
    input_variables=["documents", "question"]
)

retrieval_qa = RetrievalQA.from_chain_type(
    llm=llm,
    retriever=retriever,
    return_source_documents=True,
    chain_type_kwargs={
        "prompt": qa_prompt,
        "document_variable_name": "documents"
    }
)

user_query = "Tell me about OnePlus 6T"

response = retrieval_qa({"query": user_query})
print("Question:", user_query)
print("Generated response:", response['result'])
# Out:
# Question: Tell me about OnePlus 6T
# Generated response: The OnePlus 6T is a masterpiece of technological innovation and thoughtful design. With its cutting-edge Screen Unlock technology, you can effortlessly access your phone in an instant. The stunning 6.41 inch Optic AMOLED display provides a truly immersive viewing experience, with an impressive 86% screen-to-body ratio that will captivate your senses.
#
# Crafted with care and purpose, the OnePlus 6T features a resilient glass back that exudes elegance and durability. With Fast Charge technology, you can power up your device in just half an hour, ensuring that you are always ready to go. The operating system, powered by Android Pie, is designed to work seamlessly with you, offering a plethora of features to enhance your user experience.
#
# In summary, the OnePlus 6T is more than just a smartphone - it is a work of art that combines cutting-edge technology with thoughtful design. Experience the future of mobile technology with the OnePlus 6T and let its enchanting features delight you every day.

# %% [markdown]
# ### *Remarque :*
# *On remarque que la réponse est plus créative et moins cohérente que la précédente.*
